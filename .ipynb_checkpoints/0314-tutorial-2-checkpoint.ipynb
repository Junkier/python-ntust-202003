# %%
### 小試身手-2

# 1. 計算 1+2+3+…+100 之總和
# result = 0

# for i in range(1,101):
#     # print(i)
#     # result = result + i
#     result += i 
# print(result)

# print("-"*80)

    
# 2. 試撰寫一程式 , 列印出以下圖形
#          ******
#          *****
#          ****
#          ***
#          **
#          *
# for j in range(6,0,-1):
#     print("*"*j)

# print("******")
# print("*****")
# print("****")
# print("***")



# 3.  有一變數 name=“Jack!” , 試撰寫一程式 , 列印出下列訊息
#         JJJJJ
#         aaaa
#         ccc
#         kk
#         !

# name = "Jack!"
# cnt  = 5

# for i in range(5,0,-1):
#     print(name[5-i]*i)
#     # i=5 --> "J"*5
#     # i=4 --> "a"*4
#     # i=3 --> "c"*3
#     # ...

# for w in name:
#     print(w*cnt)
#     # cnt = cnt -1
#     cnt -= 1

    
# 4. 有一 list = [“a”, “b”, “c”, “c”, “c”, “a”, “d”, “b”, “b”, “a”, “c”]
#     試統計各字母出現次數 , 並以 dict 型式表達

### word count 

## 保留字
# data_list = ["a","b","c","c","c","a","d","b","b","a","c","c","c","c","e","f","k","a","f"]

# # {
# #     "a" : 3,
# #     "b" : 5,
# #     "c" : 1,
# #     "d" : 2
# # }

# result = {}

# for ele in data_list:
#     # print(ele)
#     if ele in result:
#         result[ele] += 1
#     else:
#         result[ele] = 1
    
# print(result)
# Out:
# 5050
# --------------------------------------------------------------------------------
# JJJJJ
# aaaa
# ccc
# kk
# !
# JJJJJ
# aaaa
# ccc
# kk
# !

# %%
# Out:
# 1*1=1
# 1*2=2
# 1*3=3
# 1*4=4
# 1*5=5
# 1*6=6
# 1*7=7
# 1*8=8
# 1*9=9
# --------------------------------------------------
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# --------------------------------------------------
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
# --------------------------------------------------
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# --------------------------------------------------
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# --------------------------------------------------
# 6*1=6
# 6*2=12
# 6*3=18
# 6*4=24
# 6*5=30
# 6*6=36
# 6*7=42
# 6*8=48
# 6*9=54
# --------------------------------------------------
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# --------------------------------------------------
# 8*1=8
# 8*2=16
# 8*3=24
# 8*4=32
# 8*5=40
# 8*6=48
# 8*7=56
# 8*8=64
# 8*9=72
# ...

# %%
# Out:
# 1*1=1  1*2=2  1*3=3  1*4=4  1*5=5  1*6=6  1*7=7  1*8=8  1*9=9
# 2*1=2  2*2=4  2*3=6  2*4=8  2*5=10 2*6=12 2*7=14 2*8=16 2*9=18
# 3*1=3  3*2=6  3*3=9  3*4=12 3*5=15 3*6=18 3*7=21 3*8=24 3*9=27
# 4*1=4  4*2=8  4*3=12 4*4=16 4*5=20 4*6=24 4*7=28 4*8=32 4*9=36
# 5*1=5  5*2=10 5*3=15 5*4=20 5*5=25 5*6=30 5*7=35 5*8=40 5*9=45
# 6*1=6  6*2=12 6*3=18 6*4=24 6*5=30 6*6=36 6*7=42 6*8=48 6*9=54
# 7*1=7  7*2=14 7*3=21 7*4=28 7*5=35 7*6=42 7*7=49 7*8=56 7*9=63
# 8*1=8  8*2=16 8*3=24 8*4=32 8*5=40 8*6=48 8*7=56 8*8=64 8*9=72
# 9*1=9  9*2=18 9*3=27 9*4=36 9*5=45 9*6=54 9*7=63 9*8=72 9*9=81

# %%
### func.
math    = [80,97,95,87,51]
eng     = [100,68,78,90,100]
chinese = [75,50,65,62,88]

print("Math Sum :",sum(math))
print("Math Avg :",sum(math)/len(math))
print("Math Max :",sorted(math,reverse=True)[0])

print("-"*80)

print("Eng Sum :",sum(eng))
print("Eng Avg :",sum(eng)/len(eng))
print("Eng Max :",sorted(eng,reverse=True)[0])

print("-"*80)

print("Chinese Sum :",sum(chinese))
print("Chinese Avg :",sum(chinese)/len(chinese))
print("Chinese Max :",sorted(chinese,reverse=True)[0])

print("-"*80)
# Out:
# Math Sum : 410
# Math Avg : 82.0
# Math Max : 97
# --------------------------------------------------------------------------------
# Eng Sum : 436
# Eng Avg : 87.2
# Eng Max : 100
# --------------------------------------------------------------------------------
# Chinese Sum : 340
# Chinese Avg : 68.0
# Chinese Max : 88
# --------------------------------------------------------------------------------

# %%
a = [2,5,-3,100,47]
print( sorted(a,reverse=True) )
# Out:
# [100, 47, 5, 2, -3]

# %%
### func 

def calculate(x,y):
    print("x :",x)
    print("y :",y)
    return [x+y,x-y,x*y,x/y]
    


# print(x+y)
# print(x-y)
# print(x*y)
# print(x/y)

# x = 12
# y = 15

# result = calculate(x,y)
# print(result)


######
### 定義
def say_hello(name):
    print("HiHi")
    print("I'm {}".format(name))
    print("Python is good!!!")

    
### 呼叫　/ 使用
say_hello("Jeff")
say_hello("Leo")
say_hello("~~~~~~~")
# Out:
# HiHi
# I'm Jeff
# Python is good!!!
# HiHi
# I'm Leo
# Python is good!!!
# HiHi
# I'm ~~~~~~~
# Python is good!!!

# %%
### func-2

def get_scores_info(scores,name):
    # print(scores)
    print("{} Sum :".format(name), sum(scores))
    print("{} Avg :".format(name), sum(scores)/len(scores))
    print("{} Max :".format(name), sorted(scores,reverse=True)[0]  )



math    = [80,97,95,87,51]
eng     = [100,68,78,90,100]
chinese = [75,50,65,62,88]

get_scores_info(math,"Math")

print("-"*80)

get_scores_info(eng,"English")

print("-"*80)

get_scores_info(chinese,"Chinese")
# Out:
# Math Sum : 410
# Math Avg : 82.0
# Math Max : 97
# --------------------------------------------------------------------------------
# English Sum : 436
# English Avg : 87.2
# English Max : 100
# --------------------------------------------------------------------------------
# Chinese Sum : 340
# Chinese Avg : 68.0
# Chinese Max : 88

# %%
### func-3
# 定義
def test_func(name,age,remark="Hello~~~~"):
    # print("[In function]")
    print(name)
    print("Age : {}".format(age))
    print("Remark : {}".format(remark))
    # print("[In function]")
    
    # return "!!!!!!"


### 主程式

# 呼叫
# print(test_func("Jeff",18))
# a = test_func("Jeff",18)
# print("-"*80)
# print(a)

test_func("Jeff",18)

print("-"*80)

test_func("Leo",22,"武漢肺炎好恐怖")

print("-"*80)

test_func("Keven",24)
# Out:
# Jeff
# Age : 18
# Remark : Hello~~~~
# --------------------------------------------------------------------------------
# Leo
# Age : 22
# Remark : 武漢肺炎好恐怖
# --------------------------------------------------------------------------------
# Keven
# Age : 24
# Remark : Hello~~~~

# %%
### func-4

## NoneType
print(a)
print(type(a))
b = None
print(type(b))

## 有無　return 
# 沒有　return 
# print("Hello")
# print(message)

# 有 return
# dataType = type("Hello")
# print(dataType)
# Out:
# None
# <class 'NoneType'>
# <class 'NoneType'>

# %%
### func-5

# def say_hello_again(name , remark="Python is good!"):
#     print("In function:",name)
#     print("I'm {}".format(name))
#     print("Remark : {}".format(remark))
#     a = 12
#     b = 13
#     print(a)
#     print(b)
#     print("My age :{}".format(a+b))
    
    

# name = "Keven!!!!!!!"
# print("Out of function:",name)
# say_hello_again("Jeff")

# # print(a)
# # print(b)
    
# print("-"*80)
    
# say_hello_again("Leo")


def say_hello_3(word):
    print(word,"~~~~")
    
def get_avg_scores(scores):
    return sum(scores)/len(scores)


# call 
def get_passed_scores(scores):
    # passed_score = 75
    
    avg = get_avg_scores(scores)
    
    
    say_hello_3("test")
    
    result = []
    
    for ele in scores:
        if ele >= avg:
            result.append(ele)
            
            
    say_hello_3("Hello!!!")
            
    return result


math = [100,95,87,42,47,90,92,95,98,90,90]

avg_score = get_avg_scores(math)

passed_score = get_passed_scores(math)

print(avg_score)
print(passed_score)
# Out:
# test ~~~~
# Hello!!! ~~~~
# 84.18181818181819
# [100, 95, 87, 90, 92, 95, 98, 90, 90]

# %%
### 大樂透
# 01 ~ 49 , 抽 6 個號碼
import random 

# print(random.random())
# print(random.randint(1,49))

def get_rand_num(n=6):
    result = []
    
    #　抽號碼 ???
    for i in range(n):
        num = random.randint(1,49)
        result.append(num)
    
    return result 


numbers = get_rand_num()
print(numbers)
# Out:
# [45, 48, 45, 26, 36, 43]

# %%
### 大樂透
# 01 ~ 49 , 抽 6 個號碼
import random 

# print(random.random())
# print(random.randint(1,49))

def get_rand_num(n=6):
    result = []
    
    # 抽號碼 
    # for i in range(n):
    #    num = random.randint(1,49)
    #    result.append(num)
    
    while True:
        num = random.randint(1,49)
        
        if num not in result:
            result.append(num)
        
        if len(result) == n:
            break

    
    return result 


numbers = get_rand_num()

print(numbers)
print(sorted(numbers))
# Out:
# [12, 1, 31, 3, 22, 16]
# [1, 3, 12, 16, 22, 31]

# %%
### 套件
import os 
print(os.getcwd())
file_names = os.listdir()
# print(file_names)

for f in file_names:
    print(f)
    
file = file_names[3]
print(os.path.join(os.getcwd(),file))

print("-"*80)

import random 

print(random.random()*100)
print(random.randint(60,100))
print(random.choice([1,2,3,4,"a","b","c"]))

# import pymongo 
# print(pymongo)
# Out:
# D:\python-ntust\python-ntust-202003
# .git
# .ipynb_checkpoints
# 0307-tutorial-1.ipynb
# 0307-tutorial-2.ipynb
# 0314-tutorial-1.ipynb
# 0314-tutorial-2.ipynb
# FAQ-series.md
# D:\python-ntust\python-ntust-202003\0307-tutorial-2.ipynb
# --------------------------------------------------------------------------------
# 37.79842871259497
# 70
# b

# %%
import requests

url = "https://news.ltn.com.tw/news/life/breakingnews/3099706"

response = requests.get(url)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
#     <head>
#         <script> var pvDomain = 'pv.ltn.com.tw'; </script>
# <script src="https://cache.ltn.com.tw/js/c.js"></script>
#         <base href='https://news.ltn.com.tw/'>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0">
#         <meta property="og:site_name" content="自由電子報" />
#         <meta name="ltn:device" content="R" />
#         <link rel="shortcut icon" href="assets/images/all/favicon.ico?upload=20170620" />
#         <link rel="apple-touch-icon" href="assets/images/all/ltn.png" />
#         <link rel="apple-touch-icon-precomposed" href="assets/images/all/ltn.png" />
#         <meta name="robots" content="index,follow" />
#         <title>武漢肺炎》新增3例確診 指揮中心：均有歐洲旅遊史 - 生活 - 自由時報電子報</title>
# ...

# %%
### 判斷資料型態
a = "test"
print(type(a))
print(type(a) == str)
print(type(a) == "str")
print(type(a) == list)
print(type(a) == dict)
print(type(123) == int)
# Out:
# <class 'str'>
# True
# False
# False
# False
# True
